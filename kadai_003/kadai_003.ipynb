# %%
import numpy as np

# %%
A = np.array([[0,1],[2,3],[4,5]])
B = np.array([[0,1,2,3,],[4,5,6,7]])
print(f"A=\n {A}")
print(f"B=\n {B}")
# Out:
# A=
#  [[0 1]
#  [2 3]
#  [4 5]]
# B=
#  [[0 1 2 3]
#  [4 5 6 7]]

# %%
C = A@B
C
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
C.max()
# Out:
# np.int64(47)
